# %% [markdown]
# # My Jupter Notebook on IBM Watson Studio

# %% [markdown]
# **Long An**
# I want to be a data scientist.

# %% [markdown]
# *I am interested in data science because I'm a curious person. I like to find the pattern behind data and solve problems with findings.*

# %% [markdown]
# ### The following code is a simple calculation.

# %%
2+3
# Out:
# 5

# %% [markdown]
# - scientific computing libraries
# - visualization
# - machine learning and deep learning
# - apache spark
#
# *[Go Google]( https://www.google.com "Google").*
#
# ```json
#
# {
#   "firstName": "Michael",
#   "lastName": "An",
#   "age": 37
# }
#
# ```
